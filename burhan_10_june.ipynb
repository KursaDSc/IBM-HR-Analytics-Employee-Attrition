# %% [markdown]
# # IBM HR Analytics Employee Attrition & Performance
#
# 📌 Uncover the factors that lead to employee attrition and explore important questions such as ‘show me a breakdown of distance from home by job role and attrition’ or ‘compare average monthly income by education and attrition’. This is a fictional data set created by IBM data scientists.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\burha\\Desktop\\Python Courses\\Fenyx IT Academi\\data manipulation_1\\WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %% [markdown]
# ##  - Data Exploration:

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %% [markdown]
# ##   - Data Preparation and Cleaning:

# %%
na_count = df.isna().sum().sum()
print("Number of NA values in the data frame: ", na_count)
# Out:
# Number of NA values in the data frame:  0

# %%
duplicate_count = df.duplicated().sum()
print("Number of duplicate rows: ", duplicate_count)
# Out:
# Number of duplicate rows:  0

# %%
### Convert categorical string columns into numeric codes :
#-----------------------------------------------------------
# Get categorical variable columns unique values series
df1 = df.loc[:, df.dtypes == 'object']
string_value_list= pd.Series({c: df1[c].unique() for c in df1})
cat_cols = string_value_list.keys()
print(string_value_list)

# Replace string data with their index value in the "string_value_list" variable
for col, uni_val in string_value_list.items():
    map_dict = {k: v for v, k in enumerate(uni_val)}
    df[col]= df[col].map(map_dict)
#-----------------------------------------------------------
# Out:
# Attrition                                                 [Yes, No]
# BusinessTravel       [Travel_Rarely, Travel_Frequently, Non-Travel]
# Department         [Sales, Research & Development, Human Resources]
# EducationField    [Life Sciences, Other, Medical, Marketing, Tec...
# Gender                                               [Female, Male]
# JobRole           [Sales Executive, Research Scientist, Laborato...
# MaritalStatus                           [Single, Married, Divorced]
# Over18                                                          [Y]
# OverTime                                                  [Yes, No]
# dtype: object

# %%
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          0               0       1102           0                 1
# 1   49          1               1        279           1                 8
# 2   37          0               0       1373           1                 2
# 3   33          1               1       1392           1                 3
# 4   27          1               0        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               0              1               1  ...
# 1          1               0              1               2  ...
# 2          2               1              1               4  ...
# 3          4               0              1               5  ...
# 4          1               2              1               7  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# # 1. What is the attrition rate for the company, and what are the factors that contribute to it?

# %%
plt.hist(df['Attrition'], bins = 10)
plt.show()

# %%
#Number of people who leave the company?
count1 = len(df[df["Attrition"] == 0])
print("Number of people who leave the company:", count1)
# Out:
# Number of people who leave the company: 237

# %%
#Number of people who DON'T leave the company?
count2 = len(df[df["Attrition"] == 1])
print("Number of people who DON'T leave the company:", count2)
# Out:
# Number of people who DON'T leave the company: 1233

# %%
#Ratios
print('The percentage of the people who leave the company: %', round(count1/(count1+count2)*100))
# Out:
# The percentage of the people who leave the company: % 16

# %% [markdown]
# # 2. Is there a relationship between distance from home and attrition, and does it vary by job role?

# %% [markdown]
# # 3. How does employee education level affect their monthly income, and does this impact attrition rates?

# %% [markdown]
# # 4. Are there any gender differences in job satisfaction, and does this impact attrition rates?

# %% [markdown]
# # 5. What factors are associated with employee performance ratings, and is there a relationship between performance ratings and attrition?

# %% [markdown]
# # 6. How the Ages affects the Attrition rate

# %%
plt.hist(df['Age'], bins = 10)
plt.show()

# %%
#Average age of the personal who left the company
average_age_yes = df[df['Attrition'] == 0]['Age'].mean()
print("Average Age for Attrition:", round(average_age_yes,2))
# Out:
# Average Age for Attrition: 33.61

# %%
#Average age of the personal who left the company
average_age_no = df[df['Attrition'] == 1]['Age'].mean()
print("Average Age for Employees:", round(average_age_no, 2))
# Out:
# Average Age for Employees: 37.56

# %%
average_age = df.groupby('Attrition')['Age'].mean()
average_age.plot(kind='bar', color='blue')
plt.xlabel('Attrition')
plt.ylabel('Average Age')
plt.title('Average Age by Attrition')
# Out:
# Text(0.5, 1.0, 'Average Age by Attrition')
